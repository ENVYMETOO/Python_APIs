# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?q=houston&appid=018a5d02bbc7412a29ca7b6e59de87ea'
response= requests.get(url).json()
display = "imperial"

# %%
#Empty list to hold needed values
result=[]
lat=[]
lng=[]
temp =[]
humidity=[]
clouds=[]
wind=[]
country= []
date=[]


#Initialize a counter to hold variables.
record_no = 0

print('Beginning Data Retrieval')
print('-' * 25) 

for city in cities:
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid=018a5d02bbc7412a29ca7b6e59de87ea&units={display}'
    response = requests.get(url).json()
    #print(response)
    if 'name' in response:
        result.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp'])
        country.append(response['sys']['country'])
        city_name =(response['name'])
        date.append(response['dt'])
        print(f'Processing Record {record_no} | {city_name}')
        record_no = record_no + 1
    else:
        print(f'City not found: {city}')
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 0 | Ludvika
# Processing Record 1 | Hilo
# Processing Record 2 | Airai
# City not found: vaitupu
# Processing Record 3 | Saint-Pierre
# Processing Record 4 | Castro
# Processing Record 5 | Port Alfred
# Processing Record 6 | Busselton
# Processing Record 7 | Hervey Bay
# Processing Record 8 | Machalí
# Processing Record 9 | Rikitea
# Processing Record 10 | Porto-Novo
# Processing Record 11 | Hobart
# Processing Record 12 | Bredasdorp
# Processing Record 13 | Tigil'
# Processing Record 14 | Tessalit
# Processing Record 15 | Hermanus
# Processing Record 16 | Mataura
# Processing Record 17 | Ixtapa
# Processing Record 18 | Gigmoto
# Processing Record 19 | Port Keats
# Processing Record 20 | Punta Arenas
# Processing Record 21 | Bluff
# Processing Record 22 | Lata
# Processing Record 23 | Jamestown
# Processing Record 24 | Beloha
# Processing Record 25 | Butaritari
# Processing Record 26 | Hasaki
# ...

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Set columns for new df
weather_info = {'City':result, 'Lat':lat, 'Lng':lng, 'Max Temp':temp,'Humidity':humidity, 'Cloudiness':clouds, 'Wind Speed':wind, 'Country':country, 'Date': date}

weather_df = pd.DataFrame(weather_info)

weather_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Ludvika  60.15   15.19     32.05       100           6        2.24
# 1          Hilo  19.73 -155.09     68.63        88          90        4.70
# 2         Airai  -8.93  125.41     61.97       100          96        2.86
# 3  Saint-Pierre -21.34   55.48     72.73        88           0       10.29
# 4        Castro -24.79  -50.01     82.13        49          40        4.36
#
#   Country        Date
# 0      SE  1608139734
# 1      US  1608139468
# 2      TL  1608139735
# 3      RE  1608139542
# 4      BR  1608139735

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    19.218533   18.532165   51.975599   72.703041   53.822898    8.551503
# std     33.367635   90.680624   31.522694   21.051682   38.253059    6.302863
# min    -54.800000 -175.200000  -43.400000   10.000000    0.000000    0.200000
# 25%     -7.970000  -57.580000   28.400000   62.000000   17.500000    4.360000
# 50%     20.930000   20.920000   61.590000   78.000000   65.000000    6.930000
# 75%     47.220000   98.980000   78.390000   88.000000   90.000000   11.410000
# max     78.220000  179.320000   96.570000  100.000000  100.000000   46.080000
#
#                Date
# count  5.590000e+02
# mean   1.608140e+09
# std    7.810358e+01
# min    1.608139e+09
# 25%    1.608140e+09
# 50%    1.608140e+09
# 75%    1.608140e+09
# max    1.608140e+09

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df.index[weather_df['Humidity'] > 100]
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

weather_df.drop(weather_df[weather_df['Humidity'] > 100].index, inplace = True)
weather_df.to_csv('clean_weather.csv')
weather_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Ludvika  60.15   15.19     32.05       100           6        2.24
# 1          Hilo  19.73 -155.09     68.63        88          90        4.70
# 2         Airai  -8.93  125.41     61.97       100          96        2.86
# 3  Saint-Pierre -21.34   55.48     72.73        88           0       10.29
# 4        Castro -24.79  -50.01     82.13        49          40        4.36
#
#   Country        Date
# 0      SE  1608139734
# 1      US  1608139468
# 2      TL  1608139735
# 3      RE  1608139542
# 4      BR  1608139735

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Max Temp'])

#Add the title
plt.title('City Latitude vs. Max Temperture')
#Add label for x axis
plt.xlabel('Latitude')
#Add label for y axis
plt.ylabel('Max Temperture (F)')
#Add grid lines
plt.grid()

plt.savefig("City Latitude vs. Max Temperture.png")
print('Observation: This data shows that temperture increases as you move further from the equator.')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Humidity'])

plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.grid()

plt.savefig('City Latitude vs. Humidity.png')
print('Observation: Humidity appears to be slightly higher and concentrated in the southern hemisphere.')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'])

plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.grid()

plt.savefig('City Latitude vs. Cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'],weather_df['Wind Speed'])

plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(%)')
plt.grid()

plt.savefig('City Latitude vs. Wind Speed.png')
print('Observation: The wind speed is primarily below 20% across both hemispheres.')

# %% [markdown]
# ## Linear Regression

# %%
nh_weather_df = (weather_df[weather_df['Lat'] > 0])
nh_weather_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ludvika  60.15   15.19     32.05       100           6        2.24
# 1         Hilo  19.73 -155.09     68.63        88          90        4.70
# 10  Porto-Novo   6.50    2.60     84.20        83          20       12.75
# 13      Tigil'  57.80  158.67     15.85        93         100        9.37
# 14    Tessalit  20.20    1.01     81.81        17           0        7.38
#
#    Country        Date
# 0       SE  1608139734
# 1       US  1608139468
# 10      BJ  1608139736
# 13      RU  1608139736
# 14      ML  1608139736

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(nh_weather_df['Lat'],nh_weather_df['Max Temp'])

plt.title('Latitude vs. Max Temperture')
plt.xlabel('Latitude')
plt.ylabel('Max Temperture (F)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_weather_df['Lat'],nh_weather_df['Max Temp'])
regress_values = nh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(nh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(0,-40),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('NH Latitude vs. Max Temperture.png')
plt.show()
# Out:
# The r-squared is: 0.7329071170958419

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
sh_weather_df = (weather_df[weather_df['Lat'] < 0])

plt.scatter(sh_weather_df['Lat'],sh_weather_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temperture (F)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_weather_df['Lat'],sh_weather_df['Max Temp'])
regress_values = sh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(sh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(-50,90),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('SH Latitude vs. Max Temperture.png')
# Out:
# The r-squared is: 0.39552875594699094

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(nh_weather_df['Lat'],nh_weather_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_weather_df['Lat'],nh_weather_df['Humidity'])
regress_values = nh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(nh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(40,20),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('NH Humidity vs. Lat Linear Regression.png')
# Out:
# The r-squared is: 0.1728236020685907

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(sh_weather_df['Lat'],sh_weather_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_weather_df['Lat'],sh_weather_df['Humidity'])
regress_values = sh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(sh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(-50,20),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('SH Humidity vs. Lat Linear Regression.png')
# Out:
# The r-squared is: 0.010808142808255967

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(nh_weather_df['Lat'],nh_weather_df['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_weather_df['Lat'],nh_weather_df['Cloudiness'])
regress_values = nh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(nh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(40,27),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('NH Cloudiness vs. Lat Linear Regression.png')
# Out:
# The r-squared is: 0.08034556631163686

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(sh_weather_df['Lat'],sh_weather_df['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_weather_df['Lat'],sh_weather_df['Cloudiness'])
regress_values = sh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(sh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(-50,10),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('SH Cloudiness vs. Lat Linear Regression.png')
# Out:
# The r-squared is: 0.08662001425401088

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(nh_weather_df['Lat'],nh_weather_df['Wind Speed'])

plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(%)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_weather_df['Lat'],nh_weather_df['Wind Speed'])
regress_values = nh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(nh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(0,40),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('NH Wind Speed vs. Lat Linear Regression.png')
# Out:
# The r-squared is: 0.024127852117175465

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(sh_weather_df['Lat'],sh_weather_df['Wind Speed'])

plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(%)')
plt.grid()

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_weather_df['Lat'],sh_weather_df['Wind Speed'])
regress_values = sh_weather_df['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(sh_weather_df['Lat'], regress_values, color = 'red')
plt.annotate(line_eq,(-50,25),fontsize = 15,color ='red')
print(f"The r-squared is: {rvalue**2}")

plt.savefig('SH Wind Speed vs. Lat Linear Regression.png')
# Out:
# The r-squared is: 0.0060225671473655715

# %%
# Out:
# The r-value is: 0.017128274759839232
